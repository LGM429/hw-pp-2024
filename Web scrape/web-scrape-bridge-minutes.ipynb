# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from random import randrange

# %%
def request(link):
    import requests 
    return requests.get(link)

# %%
request("https://www.nyc.gov/site/queenscb7/meetings/minutes.page")
# Out:
# <Response [200]>

# %%
def response(link):
    from bs4 import BeautifulSoup
    return BeautifulSoup(request(link).text, "html.parser")

# %%
response("https://www.nyc.gov/site/queenscb7/meetings/minutes.page")
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Minutes - Queens Community Board 7</title>
# <!--fixed-layout-->
# <!--ls:begin[stylesheet]-->
# <link href="/iwov-resources/fixed-layout/3-Row Simple.css" rel="stylesheet" type="text/css"/>
# <!--ls:end[stylesheet]-->
# <!--ls:begin[meta-keywords]-->
# <meta content="" name="keywords"/>
# <!--ls:end[meta-keywords]-->
# <!--ls:begin[meta-description]-->
# <meta content="" name="description"/>
# <!--ls:end[meta-description]-->
# <!--ls:begin[custom-meta-data]-->
# <!--ls:end[custom-meta-data]-->
# <!--ls:begin[meta-vpath]-->
# <meta content="" name="vpath"/>
# <!--ls:end[meta-vpath]-->
# <!--ls:begin[meta-page-locale-name]-->
# <meta content="" name="page-locale-name"/>
# <!--ls:end[meta-page-locale-name]-->
# <!--
# 					ls:begin[pre-head-injection]
# 				--><!--
# 					ls:end[pre-head-injection]
# 				--><!--
# 					ls:begin[social_media_injection]
# 				--><!--
# ...

# %%
soup = response("https://www.nyc.gov/site/queenscb7/meetings/minutes.page")

# %%
# for earlier pages I must access: https://www.nyc.gov/site/queenscb7/meetings/minutes-archive.page

# %%
# the minutes are in a "ul" like this: 
#<ul>
#<li><a href="/assets/queenscb7/downloads/pdf/minutes/2024/05-20-24-Minutes-Public-Hearing.pdf">May 20, 2024</a></li>

# %%
ul_tags = soup.find("ul").find_all("a")
base_url = "https://www.nyc.gov/site/queenscb7/meetings/minutes.page"
# links = [base_url + a_tag.get("href") for ul in ul_tags]

# %%
ul_tags
# Out:
# [<a href="/site/queenscb7/index.page">
#                        Home</a>,
#  <a href="/site/queenscb7/about/about-qcb7.page">About</a>,
#  <a href="/site/queenscb7/board-members/board-members.page">Board Members</a>,
#  <a href="/site/queenscb7/meetings/meetings.page">Meetings</a>,
#  <a href="/site/queenscb7/contact/contact.page">Contact</a>]

# %%
## I'm going to have to learn how to search for the proper tags on this
